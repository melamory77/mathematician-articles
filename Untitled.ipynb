# %%
pip install PyPDF4
# Out:
# ...
#   Created wheel for PyPDF4: filename=PyPDF4-1.27.0-py3-none-any.whl size=61253 sha256=21084cfed06b194ba37feb8c40b59f6935ebf5a43e0298d49031be9629b137ad
#   Stored in directory: c:\users\lalsk\appdata\local\pip\cache\wheels\f0\79\75\d130281ec9996a2551dbdd1836aa4beb376d53f8cdca49b4b0
# Successfully built PyPDF4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF4

file = open('C:/Users/lalsk/Desktop/d/статьи/al/al-2.pdf','rb')
pdfReader = PyPDF2.PdfFileReader(file)
count = pdfReader.numPages
st = ''
for i in range(1,count):
    page = pdfReader.getPage(i)
    output = page.extractText()
    #print(output)
    output = output.encode('latin1', errors='ignore').decode('cp1251', errors='ignore')
    st = st+' '+output
    
#pageObj = pdfReader.getPage(1)
#st = pageObj.extractText()

#st = st.encode('latin1', errors='ignore').decode('cp1251', errors='ignore')
# closing the pdf file object
file.close()

print(st)
# Out:
#  Алгебраилогика,46,2(2007),15716
# УДК512.542
# КАРТЕРОВЫПОДГРУППЫВКОНЕЧНЫХ
# ПОЧТИПРОСТЫХГРУППАХ
#
# )
# Е.П.ВДОВИН
# Встатьезавершаетсяклассификациякартеровыхподгруппвк
# онеч-
# ныхпочтипростыхгруппах.Вчастности,доказывается,чток
# артеровы
# подгруппывлюбойконечнойпочтипростойгруппесопряжены.
# Вместес
# предыдущимирезультатамиавтора,атакжерезультатами,ко
# торыеполу-
# чилиФ.ДаллаВолта,А.ЛуккинииМ.К.Тамбурини,вкачествес
# ледствия
# получается,чтокартеровыподгруппылюбойконечнойгруппы
# сопря-
# жены.
# 1.Предварительныесведения
# Напомним,чтоподгруппаконечнойгруппыназывается
# картеровой
# ,еслионанильпотентнаисамонормализуема.Всилухорошоизв
# естногоре-
# зультата,любаяконечнаяразрешимаягруппасодержитвточн
# остиодин
# сопряжјнныйкласскартеровыхподгрупп[1],иразумнопредпол
# ожить,
# чтоконечнаягруппасодержитнеболееодногосопряжјнногок
# лассакар-
# теровыхподгрупп.Справедливостьэтогопредположенияосн
# овываетсяна
# интенсивномизученииразличнымиавторамиклассовконечны
# ...

# %%
import aspose.words as aw

# %%
import os

# %%
for dirname, _, filenames in os.walk('C:/Users/lalsk/Desktop/d/статьи/conv'):
    for filename in filenames:
        my_file = os.path.join(dirname, filename)
        doc = aw.Document(my_file)
        doc.save(my_file + " convert" +".txt")

# %%
file = open('C:/Users/lalsk/Desktop/d/статьи/conv/al-161.pdf convert.txt','r',encoding = "utf-8")
file.read()
# Out:
# '\ufeff\nEvaluation Only. Created with Aspose.Words. Copyright 2003-2022 Aspose Pty Ltd.\nMath-Net.Ru\nОбщероссийский математический портал\nА. А. Бутурлакин, М. А. Гречкосеева, Циклическое строение максимальных торов в конечных классических группах, Алгебра и логика, 2007, том 46, но- мер 2, 129–156\nИспользование Общероссийского математического портала Math-Net.Ru подразумевает, что вы прочитали и согласны с пользовательским соглашением\nhttp://www.mathnet.ru/rus/agreement\nПараметры загрузки:\nIP: 92.255.216.28\n11 июня 2022 г., 21:54:15\n\nАлгебра и логика, 46, № 2 (2007), 129 156\nУДК 512.542\nЦИКЛИЧЕСКОЕ СТРОЕНИЕ МАКСИМАЛЬНЫХ ТОРОВ\nВ КОНЕЧНЫХ КЛАССИЧЕСКИХ ГРУППАХ∗)\nА.А.БУТУРЛАКИН, М.А.ГРЕЧКОСЕЕВА\nВведение\nПонятие максимального тора пришло в теорию конечных групп ли- ева типа из теории алгебраических групп. Как известно, любую конечную группу лиева типа можно представить как Op (C (σ)), где G  подходя-\nG\nщая связная простая линейная алгебраическая группа над алгебраически 
# ...

# %%
for dirname, _, filenames in os.walk('C:/Users/lalsk/Desktop/d/статьи/themes'):
    for filename in filenames:
        if(filename != "desktop.ini"):
            my_file = os.path.join(dirname, filename)
            f = open(my_file, 'r', encoding = "utf-8")
            print(filename)
            df_temp = f.read()
            temp = df_temp
            #print(temp)
            articles.append(temp)
