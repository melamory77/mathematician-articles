# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1277 sha256=d97b463be128ba3a4d393e1d38672f88b50d2bac75f6bd411bb86826aec208a1
#   Stored in directory: c:\users\lalsk\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
with open("C:/Users/lalsk/Desktop/d/статьи/res/al-252-resume.html", "r") as f:
    contents = f.read()
    soup = BeautifulSoup(contents, 'lxml')

# %%
print(soup.find_all('div'))
# Out:
# [<div style="margin: 10px; padding: 10px; text-align: center; border: 1px solid #A91818; background-color: lightyellow">
# <b>JavaScript is disabled in your browser. Please switch it on to enable full functionality of the website</b>
# </div>, <div align="center">
# <a href="http://www.mathjax.org/">
# <img alt="Powered by MathJax" border="0" hspace="35" src="/gifs/mathjax.png" title="Powered by MathJax" width="80"/>
# </a>
# <a href="http://www.crossref.org">
# <img border="0" hspace="35" src="/gifs/crossrefenabled.gif" title="Crossref" width="100"/>
# </a>
# </div>, <div class="around-button">
# <a class="button_green" href="/php/getFT.phtml?jrnid=al&amp;paperid=1&amp;what=fullt&amp;option_lang=rus" target="_blank" title="Доступен полный текст статьи">Загрузить PDF полного текста (307 kB)</a>
# </div>, <div class="around-button" style="border: none; height: auto; overflow:auto; width:100%">
# <div class="refstitle">
# <b>Список литературы:</b>
# </div>
# <div class="refslink">
# ...

# %%
udc = soup.find_all('span', class_="showUDC")

# %%
udc
# Out:
# []

# %%
print(udc[0].text.strip())
# Out:
# 510.53

# %%
soup.find(text='УДК:').parent.parent

# %%
print(m.text.strip())
# Out:
# УДК:
# 512.542

# %%
m
# Out:
# <div class="msc">
# <b>УДК:</b>
# <span class="showUDC" title="Конечные группы">512.542</span>
# </div>
